# %%
import numpy as np
class SeqEmbedding():
    def __init__(self):
        self.Dictionary = {}

    def __Sequence_to_Numeric(self,k,sequence):
        if k==0:
            temp = [0] * self.size_of_vector
            temp[len(self.Dictionary)] = 1
            self.Dictionary[sequence] = temp
            return
        nucleotide = ['A','C','G','T']
        for n in nucleotide:
            self.__Sequence_to_Numeric(k-1,sequence+n)
        return

    def fit(self, sequences, window_size, stride_size):
        self.size_of_vector = 4 ** window_size
        self.__Sequence_to_Numeric(window_size,"")

        vectorized = []

        for seq in sequences:
            first_layer_embedding = []
            for k in range(window_size, len(seq)+1, stride_size):
                try:
                    first_layer_embedding.append(self.Dictionary[seq[k-window_size:k]])
                except:
                    # exception may occur because of stride size, sometimes it may not get sequence of length window size, there will be a key not found exception in Dictionary
                    first_layer_embedding.append([0]*self.size_of_vector)
            
            vector0 = []
            vector1 = []
            for i in range(len(first_layer_embedding)):
                if i>0:
                    vector1+=first_layer_embedding[i]
                vector0+=first_layer_embedding[i]
            vector1+=first_layer_embedding[0]

            vectorized.append([vector0, vector1])
        
        # Handling inequal length problem using zero padding
        max_len = 0
        for vec in vectorized:
            max_len = max(max_len, len(vec[0]))
        for i in range(len(vectorized)):
            required = max_len - len(vectorized[i][0])

            vectorized[i][0]+=([0]*required)
            vectorized[i][0] = vectorized[i][0][:31752] # to fit into 252 * 252 pixel size, removing 120 elements
            vectorized[i][0] = np.array(vectorized[i][0])

            vectorized[i][1]+=([0]*required)
            vectorized[i][1] = vectorized[i][1][:31752] # to fit into 252 * 252 pixel size, removing 120 elements
            vectorized[i][1] = np.array(vectorized[i][1])

            vectorized[i] = np.array(vectorized[i])
            
        return np.array(vectorized)

# %%
import numpy as np
class SeqEmbedding1D():
    def __init__(self):
        self.Dictionary = {}

    def Sequence_to_Numeric(self,k,sequence):
        if k==0:
            temp = [0] * self.size_of_vector
            temp[len(self.Dictionary)] = 1
            self.Dictionary[sequence] = temp
            return
        nucleotide = ['A','C','G','T']
        for n in nucleotide:
            self.Sequence_to_Numeric(k-1,sequence+n)
        return

    def fit(self, sequences, window_size, stride_size):
        self.size_of_vector = 4 ** window_size
        self.Sequence_to_Numeric(window_size,"")

        vectorized = []

        for seq in sequences:
            first_layer_embedding = []
            for k in range(window_size, len(seq)+1, stride_size):
                try:
                    first_layer_embedding.append(self.Dictionary[seq[k-window_size:k]])
                except:
                    # exception may occur because of stride size, sometimes it may not get sequence of length window size, there will be a key not found exception in Dictionary
                    first_layer_embedding.append([0]*self.size_of_vector)
            
            vector0 = []
            for i in range(len(first_layer_embedding)):
                vector0+=first_layer_embedding[i]

            vectorized.append(vector0)
        
        # Handling inequal length problem using zero padding
        max_len = 0
        for vec in vectorized:
            max_len = max(max_len, len(vec))
        for i in range(len(vectorized)):
            required = max_len - len(vectorized[i])

            vectorized[i]+=([0]*required)
            vectorized[i] = np.array(vectorized[i])
            
        return np.array(vectorized)

# %%
import numpy as np
class SeqEmbedding2D(SeqEmbedding1D):
    def __init__(self):
        super().__init__()

    def fit(self, sequences, window_size, stride_size):
        self.size_of_vector = 4 ** window_size
        super().Sequence_to_Numeric(window_size,"")

        vectorized = []

        for seq in sequences:
            first_layer_embedding = []
            for k in range(window_size, len(seq)+1, stride_size):
                try:
                    first_layer_embedding.append(self.Dictionary[seq[k-window_size:k]])
                except:
                    # exception may occur because of stride size, sometimes it may not get sequence of length window size, there will be a key not found exception in Dictionary
                    first_layer_embedding.append([0]*self.size_of_vector)
            
            vector0 = []
            vector1 = []
            for i in range(len(first_layer_embedding)):
                if i>0:
                    vector1+=first_layer_embedding[i]
                vector0+=first_layer_embedding[i]
            vector1+=first_layer_embedding[0]

            vectorized.append([vector0, vector1])
        
        # Handling inequal length problem using zero padding
        max_len = 0
        for vec in vectorized:
            max_len = max(max_len, len(vec[0]))
        for i in range(len(vectorized)):
            required = max_len - len(vectorized[i][0])

            vectorized[i][0]+=([0]*required)
            vectorized[i][0] = np.array(vectorized[i][0])

            vectorized[i][1]+=([0]*required)
            vectorized[i][1] = np.array(vectorized[i][1])

            vectorized[i] = np.array(vectorized[i])
            
        return np.array(vectorized)

# %%
import numpy as np
class SeqEmbedding2D_V2(SeqEmbedding1D):
    def __init__(self):
        super().__init__()

    def fit(self, sequences, window_size, stride_size):
        self.size_of_vector = 4 ** window_size
        super().Sequence_to_Numeric(window_size,"")

        vectorized = []

        for seq in sequences:
            first_layer_embedding = []
            for k in range(window_size, len(seq)+1, stride_size):
                try:
                    first_layer_embedding.append(self.Dictionary[seq[k-window_size:k]])
                except:
                    # exception may occur because of stride size, sometimes it may not get sequence of length window size, there will be a key not found exception in Dictionary
                    first_layer_embedding.append([0]*self.size_of_vector)
            
            vector0 = []
            vector1 = []
            vector2 = []
            vector2+=first_layer_embedding[len(first_layer_embedding)-1]
            for i in range(len(first_layer_embedding)):
                if i>0:
                    vector1+=first_layer_embedding[i]
                vector0+=first_layer_embedding[i]
                if i<(len(first_layer_embedding)-1):
                    vector2+=first_layer_embedding[i]
            vector1+=first_layer_embedding[0]

            vectorized.append([vector0, vector1, vector2])
        
        # Handling inequal length problem using zero padding
        max_len = 0
        for vec in vectorized:
            max_len = max(max_len, len(vec[0]))
        for i in range(len(vectorized)):
            required = max_len - len(vectorized[i][0])

            vectorized[i][0]+=([0]*required)
            vectorized[i][0] = np.array(vectorized[i][0])

            vectorized[i][1]+=([0]*required)
            vectorized[i][1] = np.array(vectorized[i][1])

            vectorized[i][2]+=([0]*required)
            vectorized[i][2] = np.array(vectorized[i][2])

            vectorized[i] = np.array(vectorized[i])
            
        return np.array(vectorized)

# %%
# instance = SeqEmbedding1D()
# instance.fit(["AAG"],3,1)

# %%
import matplotlib.pyplot as plt
import tensorflow as tf
import keras
from keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, matthews_corrcoef

import numpy as np
from tqdm import tqdm
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers import Flatten
from keras.layers.convolutional import Conv2D, Conv1D
from keras.layers.convolutional import MaxPooling2D, MaxPooling1D
from keras.utils import np_utils
from scipy import stats

def get_model(X):
    model = tf.keras.models.Sequential([
                                    tf.keras.layers.Conv1D(filters=16, kernel_size=4,activation='relu',input_shape=(X.shape[1], 1)), 
                                    tf.keras.layers.MaxPooling1D(pool_size=2),
                                    tf.keras.layers.Conv1D(filters=16,kernel_size=4,activation='relu'), 
                                    tf.keras.layers.MaxPooling1D(pool_size=2),
                                    tf.keras.layers.Flatten(),
                                    tf.keras.layers.Dense(100,activation='relu'), 
                                    tf.keras.layers.Dropout(0.5), 
                                    tf.keras.layers.Dense(2,activation='softmax') 
    ])
    print(model.summary())
    model.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])
    from keras.utils.vis_utils import plot_model
    plot_model(model,to_file='model.png',show_shapes=True,show_layer_names=True)
    return model

def training(train_X, train_y, val_X, val_y, filename_best_model, first_time):
    train_X = train_X.reshape(train_X.shape[0], -1)
    val_X = val_X.reshape(val_X.shape[0], -1)
    
    if first_time == False:
        model = tf.keras.models.load_model(filename_best_model)
    else:
        model = get_model(train_X)
        
    es = EarlyStopping(monitor='val_accuracy',mode='max',verbose=1,patience=200)
    mc = ModelCheckpoint(filename_best_model,monitor='val_accuracy',mode='max',verbose=1,save_best_only=True, save_weights_only=False)

    model.fit(train_X,train_y, validation_data=(val_X,val_y), epochs=300,batch_size=256,callbacks=[es,mc])

    return

def testing(test_X, test_y, filename_best_model, output_file):
    test_X = test_X.reshape(test_X.shape[0], -1)

    # model = get_model(test_X)
    model = tf.keras.models.load_model(filename_best_model)

    p = model.predict(test_X)
    prediction = []
    for x in p:
        if(x[0]>x[1]):
            prediction.append(0)
        else:
            prediction.append(1)

    f = open(output_file, "w")
    f.write(f'Accuracy: {accuracy_score(test_y,prediction)}\n')
    f.write(f'Precision: {precision_score(test_y,prediction)}\n')
    f.write(f'Recall: {recall_score(test_y,prediction)}\n')
    f.write(f'F1 Score: {f1_score(test_y,prediction)}\n')
    f.write(f'MCC Score: {matthews_corrcoef(test_y,prediction)}\n')
    f.close()
    return

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
import numpy as np
file = open("/content/drive/MyDrive/Introduction to Bioinformatics/Project Proposal/Dataset/histone/H3K4me2.txt","r")
sequences = []
class_label = []
for line in file:
    if '>' in line:
        continue
    line = line[:-1]
    if len(line)>1:
        sequences.append(line)
    else:
        class_label.append(int(line)) 
file.close()
removable = []
for i in range(len(sequences)):
    if len(sequences[i]) < 500:
        removable.append(i)

iter = 0
for x in removable:
    sequences.pop(x-iter)
    class_label.pop(x-iter)
    iter+=1

class_label = np.array(class_label)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(sequences, class_label, test_size=0.2, random_state=42, stratify=class_label)

output_file = 'SeqEmbedding1D_best_model.txt'
filename_best_model = 'SeqEmbedding1D_best_model.tf'

# training phase
train_sz = (5000.0/len(X_train))
first_time = True
while train_sz<1.00:
    X_train_val, X_train, y_train_val, y_train = train_test_split(X_train, y_train, train_size = train_sz, random_state=42, stratify=y_train)

    # for one batch
    instance = SeqEmbedding1D()
    X_train_val = instance.fit(sequences = X_train_val, window_size = 3, stride_size = 1)
    train_X, val_X, train_y, val_y = train_test_split(X_train_val, y_train_val, test_size=0.1, random_state=42, stratify = y_train_val)
    training(train_X, train_y, val_X, val_y,filename_best_model,first_time)

    train_sz = (5000.0/len(X_train))
    first_time = False

X_train_val = X_train
y_train_val = y_train
instance = SeqEmbedding1D()
X_train_val = instance.fit(sequences = X_train_val, window_size = 3, stride_size = 1)
train_X, val_X, train_y, val_y = train_test_split(X_train_val, y_train_val, test_size=0.1, random_state=42, stratify = y_train_val)
training(train_X, train_y, val_X, val_y,filename_best_model,first_time)

#test phase
instance = SeqEmbedding1D()
X_test = instance.fit(X_test, window_size = 3, stride_size = 1)
testing(X_test, y_test, filename_best_model, output_file)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv1d (Conv1D)             (None, 31869, 16)         80
#
#  max_pooling1d (MaxPooling1D  (None, 15934, 16)        0
#  )
#
#  conv1d_1 (Conv1D)           (None, 15931, 16)         1040
#
#  max_pooling1d_1 (MaxPooling  (None, 7965, 16)         0
#  1D)
#
#  flatten (Flatten)           (None, 127440)            0
#
#  dense (Dense)               (None, 100)               12744100
#
#  dropout (Dropout)           (None, 100)               0
#
#  dense_1 (Dense)             (None, 2)                 202
#
# ...
# Total params: 12,745,422
# Trainable params: 12,745,422
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/300
# 18/18 [==============================] - ETA: 0s - loss: 0.7757 - accuracy: 0.5609
# ...

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(sequences, class_label, test_size=0.15, random_state=42, stratify=class_label)

output_file = 'SeqEmbedding2D_best_model.txt'
filename_best_model = 'SeqEmbedding2D_best_model.tf'

# training phase
train_sz = (3000.0/len(X_train))
first_time = True
while train_sz<1.00:
    X_train_val, X_train, y_train_val, y_train = train_test_split(X_train, y_train, train_size = train_sz, random_state=42, stratify=y_train)

    # for one batch
    instance = SeqEmbedding2D()
    X_train_val = instance.fit(sequences = X_train_val, window_size = 3, stride_size = 1)
    train_X, val_X, train_y, val_y = train_test_split(X_train_val, y_train_val, test_size=0.1, random_state=42, stratify = y_train_val)
    training(train_X, train_y, val_X, val_y,filename_best_model,first_time)

    train_sz = (3000.0/len(X_train))
    first_time = False

X_train_val = X_train
y_train_val = y_train
instance = SeqEmbedding2D()
X_train_val = instance.fit(sequences = X_train_val, window_size = 3, stride_size = 1)
train_X, val_X, train_y, val_y = train_test_split(X_train_val, y_train_val, test_size=0.1, random_state=42, stratify = y_train_val)
training(train_X, train_y, val_X, val_y,filename_best_model,first_time)

#test phase
instance = SeqEmbedding2D()
X_test = instance.fit(X_test, window_size = 3, stride_size = 1)
testing(X_test, y_test, filename_best_model, output_file)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(sequences, class_label, test_size=0.15, random_state=42, stratify=class_label)

output_file = 'SeqEmbedding2D_V2_best_model.txt'
filename_best_model = 'SeqEmbedding2D_V2_best_model.tf'

# training phase
train_sz = (2000.0/len(X_train))
first_time = True
while train_sz<1.00:
    X_train_val, X_train, y_train_val, y_train = train_test_split(X_train, y_train, train_size = train_sz, random_state=42, stratify=y_train)

    # for one batch
    instance = SeqEmbedding2D_V2()
    X_train_val = instance.fit(sequences = X_train_val, window_size = 3, stride_size = 1)
    train_X, val_X, train_y, val_y = train_test_split(X_train_val, y_train_val, test_size=0.1, random_state=42, stratify = y_train_val)
    training(train_X, train_y, val_X, val_y,filename_best_model,first_time)

    train_sz = (2000.0/len(X_train))
    first_time = False

X_train_val = X_train
y_train_val = y_train
instance = SeqEmbedding2D_V2()
X_train_val = instance.fit(sequences = X_train_val, window_size = 3, stride_size = 1)
train_X, val_X, train_y, val_y = train_test_split(X_train_val, y_train_val, test_size=0.1, random_state=42, stratify = y_train_val)
training(train_X, train_y, val_X, val_y,filename_best_model,first_time)

#test phase
instance = SeqEmbedding2D_V2()
X_test = instance.fit(X_test, window_size = 3, stride_size = 1)
testing(X_test, y_test, filename_best_model, output_file)

# %% [markdown]
# # Applying Word2Vec for Sequence Embedding

# %%
from gensim.models import Word2Vec, KeyedVectors
import pandas as pd
import nltk
nltk.download('punkt')

class Word2Vec_Seq():
    def __init__(self):
        pass
    def SeqtoSen(self,sequences):
        sentences = []
        for sequence in sequences:
            sentence = ""
            for i in range(len(sequence)-2):
                if (len(sentence)>0):
                    sentence = sentence + " ";
                sentence = sentence + sequence[i:i+3]
            sentences.append(sentence)
        return np.array(sentences,dtype='object')

    def fit(self, sequences):
        sequence_to_sentences = SeqtoSen(sequences)
        tokenized_seq = [nltk.word_tokenize(sentence) for sentence in sequence_to_sentences]
        model = Word2Vec(tokenized_seq, min_count=1, size = 64)
        embedded_sequences = []

        for tokenized_one_seq in tokenized_seq:
            embedded_one = []
            for token in tokenized_one_seq:
                embedded_one += list(model.wv[token])
            embedded_sequences.append(np.array(embedded_one))
        return np.array(embedded_sequences)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(sequences, class_label, test_size=0.15, random_state=42, stratify=class_label)

output_file = 'Word2Vec_Seq_best_model.txt'
filename_best_model = 'Word2Vec_Seq_best_model.tf'

# training phase
train_sz = (2000.0/len(X_train))
first_time = True
while train_sz<1.00:
    X_train_val, X_train, y_train_val, y_train = train_test_split(X_train, y_train, train_size = train_sz, random_state=42, stratify=y_train)

    # for one batch
    instance = Word2Vec_Seq()
    X_train_val = instance.fit(sequences = X_train_val)
    train_X, val_X, train_y, val_y = train_test_split(X_train_val, y_train_val, test_size=0.1, random_state=42, stratify = y_train_val)
    training(train_X, train_y, val_X, val_y,filename_best_model,first_time)

    train_sz = (2000.0/len(X_train))
    first_time = False

X_train_val = X_train
y_train_val = y_train
instance = Word2Vec_Seq()
X_train_val = instance.fit(sequences = X_train_val)
train_X, val_X, train_y, val_y = train_test_split(X_train_val, y_train_val, test_size=0.1, random_state=42, stratify = y_train_val)
training(train_X, train_y, val_X, val_y,filename_best_model,first_time)

#test phase
instance = Word2Vec_Seq()
X_test = instance.fit(X_test)
testing(X_test, y_test, filename_best_model, output_file)

# %% [markdown]
# # Applying BERT for Sequence Embedding

# %%
# !pip install git+https://github.com/khalidsaifullaah/BERTify
# Out:
# ...
#   Cloning https://github.com/khalidsaifullaah/BERTify to /tmp/pip-req-build-v5yt21yb
#   Running command git clone -q https://github.com/khalidsaifullaah/BERTify /tmp/pip-req-build-v5yt21yb
# ...
#      |████████████████████████████████| 15.7 MB 4.3 MB/s
# ...
#      |████████████████████████████████| 831.4 MB 2.7 kB/s
# ...
#      |████████████████████████████████| 76 kB 4.4 MB/s
# ...
#      |████████████████████████████████| 2.8 MB 37.1 MB/s
# ...
#      |████████████████████████████████| 596 kB 48.3 MB/s
# ...
#      |████████████████████████████████| 61 kB 485 kB/s
# ...
#      |████████████████████████████████| 3.3 MB 49.8 MB/s
# ...
#      |████████████████████████████████| 895 kB 39.9 MB/s
# ...
#   Created wheel for BERTify: filename=BERTify-0.0.3-py3-none-any.whl size=6176 sha256=0aba0558a9397621e3dd33612740e36dd440c8fe3f480d517390988f985611b5
#   Stored in directory: /tmp/pip-ephem-wheel-cache-dnh95nc3/wheels/c9/72/13/2d6804d235c57226b52fc6f73fe541577a23d6bdc8ec571517
# Successfully built BERTify
# ...

# %%
from bertify import BERTify
class BERT_Seq(Word2Vec_Seq):
    def __init__(self):
        super().__init__()
        self.en_bertify = BERTify(
            lang="en",
            last_four_layers_embedding=True
        )
    def fit(self,sequences):
        sequence_to_sentences = super().SeqtoSen(sequences)
        en_embeddings = self.en_bertify.embedding(sequence_to_sentences)
        return en_embeddings

# %%
instance = BERT_Seq()
arrays = instance.fit(sequences[:500])
arrays.shape
# Out:
# ##########
# Using cuda for computation
# using bert-base-uncased model for en embedding
# ##########
# Downloading:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/570 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/440M [00:00<?, ?B/s]
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertModel: ['cls.seq_relationship.weight', 'cls.seq_relationship.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.decoder.weight', 'cls.predictions.bias', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias']
# ...

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(sequences, class_label, test_size=0.15, random_state=42, stratify=class_label)

output_file = 'BERT_Seq_best_model.txt'
filename_best_model = 'BERT_Seq_best_model.tf'

# training phase
train_sz = (2000.0/len(X_train))
first_time = True
while train_sz<1.00:
    X_train_val, X_train, y_train_val, y_train = train_test_split(X_train, y_train, train_size = train_sz, random_state=42, stratify=y_train)

    # for one batch
    instance = BERT_Seq()
    X_train_val = instance.fit(sequences = X_train_val)
    train_X, val_X, train_y, val_y = train_test_split(X_train_val, y_train_val, test_size=0.1, random_state=42, stratify = y_train_val)
    training(train_X, train_y, val_X, val_y,filename_best_model,first_time)

    train_sz = (2000.0/len(X_train))
    first_time = False

X_train_val = X_train
y_train_val = y_train
instance = BERT_Seq()
X_train_val = instance.fit(sequences = X_train_val)
train_X, val_X, train_y, val_y = train_test_split(X_train_val, y_train_val, test_size=0.1, random_state=42, stratify = y_train_val)
training(train_X, train_y, val_X, val_y,filename_best_model,first_time)

#test phase
instance = BERT_Seq()
X_test = instance.fit(X_test)
testing(X_test, y_test, filename_best_model, output_file)
# Out:
# ##########
# Using cuda for computation
# using bert-base-uncased model for en embedding
# ##########
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertModel: ['cls.seq_relationship.weight', 'cls.seq_relationship.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.decoder.weight', 'cls.predictions.bias', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
#   0%|          | 0/32 [00:00<?, ?it/s]
# ...
